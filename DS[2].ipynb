# %% [markdown]
# <a href="https://colab.research.google.com/github/abylaip/abylaip/blob/main/DS%5B2%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/My Drive/flight_delays.csv'
df = pd.read_csv(file_path)

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x=df.index, y=df['NK'])
# Out:
# <Axes: xlabel='None', ylabel='NK'>

# %%
sns.heatmap(data=df, annot=True)
# Out:
# <Axes: >

# %%
file_path = '/content/drive/My Drive/ign_scores.csv'
df = pd.read_csv(file_path)
print(df.head())
# Out:
#            Platform    Action  Action, Adventure  Adventure  Fighting  \
# 0         Dreamcast  6.882857           7.511111   6.281818  8.200000
# 1  Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# 2    Game Boy Color  6.272727           8.166667   5.307692  4.500000
# 3          GameCube  6.532584           7.608333   6.753846  7.422222
# 4      Nintendo 3DS  6.670833           7.481818   7.414286  6.614286
#
#    Platformer    Puzzle       RPG    Racing   Shooter  Simulation    Sports  \
# 0    8.340000  8.088889  7.700000  7.042500  7.616667    7.628571  7.272222
# 1    6.970588  6.532143  7.542857  6.657143  6.444444    6.928571  6.694444
# 2    6.352941  6.583333  7.285714  5.897436  4.500000    5.900000  5.790698
# 3    6.665714  6.133333  7.890909  6.852632  6.981818    8.028571  7.481319
# 4    7.503448  8.000000  7.719231  6.900000  7.033333    7.700000  6.388889
#
#    Strategy
# 0  6.433333
# 1  7.175000
# 2  7.400000
# 3  7.116667
# 4  7.900000

# %%
plt.figure(figsize=(14, 7))
sns.barplot(x=df['Racing'], y=df['Platform'])
# Out:
# <Axes: xlabel='Racing', ylabel='Platform'>

# %%
df_numeric = df.set_index('Platform')
sns.heatmap(df_numeric, annot=True)
# Out:
# <Axes: ylabel='Platform'>

# %%
file_path = '/content/drive/My Drive/insurance.csv'
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.figure(figsize=(14, 7))
sns.scatterplot(x=df['bmi'], y=df['charges'], hue=df['smoker'])
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %%
# plt.figure(figsize=(14, 7))
sns.lmplot(x='bmi', y='charges', hue='smoker', data=df)

# %%
sns.swarmplot(x=df['smoker'], y=df['charges'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
file_path = '/content/drive/My Drive/candy.csv'
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    id competitorname chocolate fruity caramel peanutyalmondy nougat  \
# 0   0      100 Grand       Yes     No     Yes             No     No
# 1   1   3 Musketeers       Yes     No      No             No    Yes
# 2   2      Air Heads        No    Yes      No             No     No
# 3   3     Almond Joy       Yes     No      No            Yes     No
# 4   4      Baby Ruth       Yes     No     Yes            Yes    Yes
#
#   crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# 0              Yes   No  Yes       No         0.732         0.860   66.971725
# 1               No   No  Yes       No         0.604         0.511   67.602936
# 2               No   No   No       No         0.906         0.511   52.341465
# 3               No   No  Yes       No         0.465         0.767   50.347546
# 4               No   No  Yes       No         0.604         0.767   56.914547

# %%
sns.regplot(x=df['sugarpercent'], y=df['winpercent'])
# Out:
# <Axes: xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.scatterplot(x=df['pricepercent'], y=df['winpercent'], hue=df['chocolate'])
# Out:
# <Axes: xlabel='pricepercent', ylabel='winpercent'>

# %%
sns.lmplot(x='pricepercent', y='winpercent', hue='chocolate', data=df)

# %%
sns.swarmplot(x=df['chocolate'], y=df['winpercent'])
# Out:
# <Axes: xlabel='chocolate', ylabel='winpercent'>

# %%
file_path = '/content/drive/My Drive/iris.csv'
df = pd.read_csv(file_path)
print(df.head())
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa

# %%
sns.distplot(a=df['Petal Length (cm)'], kde=False)
# Out:
# <ipython-input-30-f62800749997>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=df['Petal Length (cm)'], kde=False)
# <Axes: xlabel='Petal Length (cm)'>

# %%
sns.kdeplot(data=df['Petal Length (cm)'], fill=True)
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %%
sns.jointplot(x=df['Petal Length (cm)'], y=df['Sepal Width (cm)'], kind="kde", fill=True)

# %%
vir_path = '/content/drive/My Drive/iris_virginica.csv'
vir_data = pd.read_csv(vir_path)
ver_path = '/content/drive/My Drive/iris_versicolor.csv'
ver_data = pd.read_csv(ver_path)
set_path = '/content/drive/My Drive/iris_setosa.csv'
set_data = pd.read_csv(set_path)
print(df.head())
# Out:
#    Id  Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  \
# 0   1                5.1               3.5                1.4
# 1   2                4.9               3.0                1.4
# 2   3                4.7               3.2                1.3
# 3   4                4.6               3.1                1.5
# 4   5                5.0               3.6                1.4
#
#    Petal Width (cm)      Species
# 0               0.2  Iris-setosa
# 1               0.2  Iris-setosa
# 2               0.2  Iris-setosa
# 3               0.2  Iris-setosa
# 4               0.2  Iris-setosa

# %%
sns.distplot(a=set_data['Petal Length (cm)'], label="Iris setosa", kde=False)
sns.distplot(a=ver_data['Petal Length (cm)'], label="Iris versicolor", kde=False)
sns.distplot(a=vir_data['Petal Length (cm)'], label="Iris virginica", kde=False)
# Out:
# <ipython-input-34-b6f5b049ba30>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a=set_data['Petal Length (cm)'], label="Iris setosa", kde=False)
# <ipython-input-34-b6f5b049ba30>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
sns.kdeplot(data=set_data['Petal Length (cm)'], label="Iris setosa", fill=True)
sns.kdeplot(data=ver_data['Petal Length (cm)'], label="Iris versicolor", fill=True)
sns.kdeplot(data=vir_data['Petal Length (cm)'], label="Iris virginica", fill=True)
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/cancer.csv'
data = pd.read_csv(path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#          Id Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# 0   8510426         B         13.540           14.36             87.46
# 1   8510653         B         13.080           15.71             85.63
# 2   8510824         B          9.504           12.44             60.34
# 3    854941         B         13.030           18.42             82.61
# 4  85713702         B          8.196           16.84             51.71
#
#    Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# 0        566.3            0.09779             0.08129           0.06664
# 1        520.0            0.10750             0.12700           0.04568
# 2        273.9            0.10240             0.06492           0.02956
# 3        523.8            0.08983             0.03766           0.02562
# ...

# %% [markdown]
# # **This is how you can get information using condition instead of manually checking**

# %%
filtered_data = data[data['Id'] == 842517]

plt.figure(figsize=(10, 5))
sns.barplot(x='Id', y='Radius (mean)', data=filtered_data)
# Out:
# <Axes: xlabel='Id', ylabel='Radius (mean)'>

# %%
sns.kdeplot(data=data['Area (worst)'], fill=True)
# Out:
# <Axes: xlabel='Area (worst)', ylabel='Density'>
